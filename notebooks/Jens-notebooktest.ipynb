# %%
from pathlib import Path



# LOAD ALL PROCESSING CLASSES
from ama_tlbx.data import LifeExpectancyDataset, LECol

from ama_tlbx.analysis import (
    IQROutlierDetector,
    IsolationForestOutlierDetector,
    ZScoreOutlierDetector,
)
from ama_tlbx.plotting import (
    plot_correlation_heatmap,
    plot_explained_variance,
    plot_loadings_heatmap,
    plot_target_correlations,
    plot_top_correlated_pairs,
)

# %%
DATA_DIR = Path.cwd().parent / "_data"
if not DATA_DIR.exists():
    DATA_DIR = Path.cwd() / "_data"

assert DATA_DIR.exists(), f"Data directory {DATA_DIR} does not exist."

dataset = LifeExpectancyDataset.from_csv(
    DATA_DIR / "life_expectancy_data.csv",
    aggregate_by_country=True,  # Average across years per country
    drop_missing_target=True,  # Remove rows without life expectancy
)

print(f"   Shape: {dataset.df.shape}")
print(f"   Countries: {dataset.df.shape[0]}")
print(f"   Features: {dataset.df.shape[1] - len(dataset.identifier_columns)}")

print("\nColumn normalization examples:")
print(f"   'Life expectancy ' -> '{LECol.LIFE_EXPECTANCY}'")
print(f"   ' BMI ' -> '{LECol.BMI}'")
print(f"   'Income composition of resources' → '{LECol.INCOME_COMPOSITION}'")

dataset.df
# Out:
#    Shape: (183, 22)
#    Countries: 183
#    Features: 19
#
# Column normalization examples:
#    'Life expectancy ' -> 'life_expectancy'
#    ' BMI ' -> 'bmi'
#    'Income composition of resources' → 'income_composition_of_resources'
#                                 country  adult_mortality   alcohol       bmi  \
# 0                           Afghanistan         269.0625  0.014375  15.51875
# 1                               Albania          45.0625  4.848750  49.06875
# 2                               Algeria         108.1875  0.406667  48.74375
# 3                                Angola         328.5625  5.740667  18.01875
# 4                   Antigua and Barbuda         127.5000  7.949333  38.42500
# ..                                  ...              ...       ...       ...
# 178  Venezuela (Bolivarian Republic of)         163.0000  7.420000  54.48750
# 179                            Viet Nam         126.5625  3.087333  11.18750
# 180                               Yemen         211.8125  0.047333  33.48750
# 181                              Zambia         354.3125  2.239333  17.45000
# 182                            Zimbabwe         462.3750  4.482000  25.13750
#
#      diphtheria          gdp  hepatitis_b  hiv_aids  \
# 0       52.3125   340.015425    64.562500   0.10000
# 1       98.0625  2119.726679    98.000000   0.10000
# 2       91.8750  2847.853392    78.000000   0.10000
# 3       47.6875  1975.143045    70.222222   2.36875
# 4       98.3125  9759.305728    98.266667   0.12500
# ..          ...          ...          ...       ...
# 178     68.5000  7389.061605    66.250000   0.10000
# 179     91.7500  7389.061605    87.538462   0.14375
# 180     72.6250  7389.061605    55.687500   0.10000
# 181     74.2500   811.811841    69.818182  11.93125
# 182     75.1875   410.980194    70.562500  23.26250
#
#      income_composition_of_resources  infant_deaths  ...  \
# 0                           0.415375        78.2500  ...
# 1                           0.709875         0.6875  ...
# 2                           0.694875        20.3125  ...
# 3                           0.458375        83.7500  ...
# 4                           0.488625         0.0000  ...
# ..                               ...            ...  ...
# 178                         0.726812         9.3750  ...
# 179                         0.627062        29.1875  ...
# 180                         0.475500        39.3750  ...
# 181                         0.498437        33.4375  ...
# 182                         0.439125        26.5625  ...
#
#      percentage_expenditure    polio    population  schooling  \
# 0                 34.960110  48.3750  9.972260e+06    8.21250
# 1                193.259091  98.1250  6.969116e+05   12.13750
# 2                236.185241  91.7500  2.164983e+07   12.71250
# 3                102.100268  46.1250  1.014710e+07    8.04375
# 4               1001.585226  96.9375  1.274585e+07    8.84375
# ..                      ...      ...           ...        ...
# 178                0.000000  74.6875  1.274585e+07   12.78750
# 179                0.000000  94.9375  1.274585e+07   11.51250
# 180                0.000000  67.1250  1.274585e+07    8.50625
# 181               89.650407  64.3750  6.260246e+06   11.21250
# 182               20.364271  75.6250  8.021343e+06    9.82500
#
#      thinness_1_19_years  thinness_5_9_years  total_expenditure  \
# 0               16.58125            15.58125           8.252500
# 1                1.61875             1.70000           5.945625
# 2                6.09375             5.97500           4.604000
# 3                6.19375             6.66875           3.919333
# 4                3.42500             3.37500           4.791333
# ..                   ...                 ...                ...
# 178              1.65000             1.56250           4.998667
# 179             14.92500            15.62500           5.977333
# 180             13.83125            13.75000           5.005333
# 181              6.88125             6.76250           5.824000
# 182              7.01250             6.98750           6.158667
#
#      under_five_deaths      status       year
# 0             107.5625  Developing 2015-01-01
# 1               0.9375  Developing 2015-01-01
# 2              23.5000  Developing 2015-01-01
# 3             132.6250  Developing 2015-01-01
# 4               0.0000  Developing 2015-01-01
# ..                 ...         ...        ...
# 178            10.7500  Developing 2015-01-01
# 179            36.5000  Developing 2015-01-01
# 180            51.6250  Developing 2015-01-01
# 181            52.3750  Developing 2015-01-01
# 182            40.8125  Developing 2015-01-01
#
# [183 rows x 22 columns]

# %%
from ama_tlbx.analysis import (
    ColumnConcatenator,
)


# SELECT COLUMNS FOR CONCAT
selected_columns = [
    LECol.HEPATITIS_B,
    LECol.POLIO,
    LECol.DIPHTHERIA,
]

# INITIALISE THE CONCATINATOR
column_concatinator = ColumnConcatenator(dataset)

trimmed_dataset = column_concatinator.concatenate(
    columns=selected_columns,
    new_column_name="Immunisation Rate"
)

print("trimmed dataset")
print(trimmed_dataset.df["Immunisation Rate"])
# Out:
# trimmed dataset
# 0      55.032880
# 1      98.062408
# 2      87.303285
# 3      54.538586
# 4      97.850537
#          ...
# 178    69.776710
# 179    91.410879
# 180    65.305836
# 181    69.592487
# 182    73.819366
# Name: Immunisation Rate, Length: 183, dtype: float64

# %%
from ama_tlbx.analysis import (
    ColumnConcatenator,
)

corr_analyzer = dataset.make_correlation_analyzer(
    columns=selected_columns,
    standardized=True,  # Use standardized data
    include_target=True,
)
corr_result = corr_analyzer.compute(top_n_pairs=10)
plot_correlation_heatmap(corr_result)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 10
#       1 from ama_tlbx.analysis import (
#       2     ColumnConcatenator,
#       3 )
#       5 corr_analyzer = dataset.make_correlation_analyzer(
#       6     columns=selected_columns,
#       7     standardized=True,  # Use standardized data
#       8     include_target=True,
#       9 )
# ---> 10 corr_result = corr_analyzer.compute(top_n_pairs=10)
#      11 plot_correlation_heatmap(corr_result)
#
# File ~\Documents\GitHub\ama_ws25\ama_tlbx\ama_tlbx\analysis\correlation_analyzer.py:100, in CorrelationAnalyzer.compute(self, top_n_pairs)
#      98 target_corr = None
#      99 if self._view.target_col:
# --> 100     target_corr = self.get_target_correlations()
#     101 return CorrelationResult(
#     102     matrix=matrix,
#     103     pretty_by_col=dict(self._view.pretty_by_col),
#     104     feature_pairs=pairs,
#     105     target_correlations=target_corr,
#     106 )
#
# File ~\Documents\GitHub\ama_ws25\ama_tlbx\ama_tlbx\analysis\correlation_analyzer.py:84, in CorrelationAnalyzer.get_target_correlations(self)
#      82 if self._view.target_col not in corr_matrix.index:
#      83     msg = f"Target column '{self._view.target_col}' not found in data"
# ---> 84     raise ValueError(msg)
#      86 correlations = corr_matrix.loc[self._view.target_col].drop(self._view.target_col)
#      87 return (
#      88     correlations.sort_values(ascending=False)
#      89     .to_frame(name="correlation")
#      90     .assign(feature=lambda d: d.index)
#      91     .reset_index(drop=True)
#      92 )
#
# ValueError: Target column 'life_expectancy' not found in data
